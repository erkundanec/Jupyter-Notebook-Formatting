# %% [markdown]
# # How to set formatting for the Jupyter-Notebook Docs

# %%
import os
from IPython.core.display import HTML
def load_style(directory = 'styleFiles', name='custom.css'):
        styles = open(os.path.join(directory, name), 'r').read()
        return HTML(styles)
load_style()
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Lora');
#
# .CodeMirror pre, .CodeMirror-dialog, .CodeMirror-dialog .CodeMirror-search-field, .terminal-app .terminal {
#     font-family: YOUR-FAV-FONT;
#     font-size: 12pt;
# }
#
# .CodeMirror pre {
#     font-family: 'Source Code Pro', Consolas, monocco, monospace;
# }
#     div.cell{
#         //width: 950px;
#         margin-left: 0% !important;
#         margin-right: auto;
#     }
#     div.text_cell_render{
#         font-family: 'Lora';
#         line-height: 125%;
#         font-size: 130%;
#         text-align: justify;
#         text-justify:inter-word;
#     }
#     div.text_cell code {
#         background: transparent;
#         color: #000000;
#         font-weight: 400;
#         font-size: 12pt;
#         font-family:  'Source Code Pro', Consolas, monocco, monospace;
#    }
#     h1 {
#         font-family: "Ubuntu";
# 	}
#
# ...

# %% [markdown]
# # Code Documentation Formatting

# %% [raw]
# '''============================ mySegAutoencoder.py file ============================= %
#
# Description                  : Sementic segmentation using Autoencoder
# Input parameter              : input files are original color image and its mark image
# Output parameter             :
# Subroutine  called           : NA
# Called by                    : NA
# Reference                    :
# Author of the code           : Kundan Kumar
# Date of creation             : 13 April 2019
# ------------------------------------------------------------------------------------------------------- %
# Modified on                  : 07 June 2019
# Modification details         :
# Modified By                  : Kundan Kumar
# ===================================================================== %
#    Copy righted by ECE Department, ITER, SOA University India.
# ===================================================================== %'''

# %% [markdown]
# # Table of Contents
# 1. [Motivation for Support Vector Machines](#motivation)
#
#     1.1 [Dopping](#nan)
#     1.2 [Test](#third)
#
# # Title of the project
# ## Section
# ### Subsection
#
# **Bold Font** or __Bold Font__
# *Italic* or _Italic_
# --scractched Text--
#
# Markdown doesn't support underline. But you can do that using HTML <u>Test</u>
#
# List
# - item
# - item
#  - item
#  - item
#
#
#
# 1. item
# 2. item
#  1. sub item
#  2. sub item
#
#
# http://www.github.com/
#
# [Github](http://www.github.com/)
#
# ## Images
#
# ![title](firstImage.jpeg)
#
#
# ## Quotes
# > Why, oh why, Javascript?? Wars, Famine, planetary destruction...
# > [Kundan](https://google.com)
#
# ## Tables
# | Tables | Are | Cool|
# |--------|:---:| ---:|
# | test 1  |test2| test3|
#
# Python Code:
# ```python
# x=5
# print "my name is khan"
# ```
#
# ## Latex
# You can use Latex in line by like this $y=x^2$ or in block like this $$y=x^2$$

# %% [markdown]
# <a id = "motivation"></a>
# ## Link code is here

# %%
print("hello world")
# Out:
# hello world

# %%
name = "john"

# %%
print(name)
# Out:
# john
